# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
#gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_Database.csv")
city_data_df.head(10)
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0        Hermanus      ZA  2021-12-05 22:53:07 -34.4187   19.2345
# 1        1         Calamar      CO  2021-12-05 22:53:07  10.2511  -74.9146
# 2        2          Kodiak      US  2021-12-05 22:53:08  57.7900 -152.4072
# 3        3        Cherskiy      RU  2021-12-05 22:53:08  68.7500  161.3000
# 4        4    Punta Arenas      CL  2021-12-05 22:52:21 -53.1500  -70.9167
# 5        5  Ribeira Grande      PT  2021-12-05 22:53:08  38.5167  -28.7000
# 6        6          Sabang      ID  2021-12-05 22:50:41   5.8933   95.3214
# 7        7     Morgan City      US  2021-12-05 22:53:09  29.6994  -91.2068
# 8        8         Mataura      NZ  2021-12-05 22:53:09 -46.1927  168.8643
# 9        9       Dharchula      IN  2021-12-05 22:53:09  29.8500   80.5333
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     60.91        94         100       10.36          light rain
# 1     84.15        76          43        8.43    scattered clouds
# 2     34.07        84         100       13.33     overcast clouds
# 3    -46.23       100          86        4.12     overcast clouds
# 4     55.51        41          20       20.71          few clouds
# 5     63.93        73          72        7.83       broken clouds
# 6     81.00        77          90       14.34     overcast clouds
# 7     75.20        78          20        4.61          few clouds
# 8     54.48        47          92        5.06     overcast clouds
# 9     51.24        83          86        5.86     overcast clouds

# %%
gmaps.configure(api_key=g_key)

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 78
# What is the maximum temperature you would like for your trip? 85

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 1         1         Calamar      CO  2021-12-05 22:53:07  10.2511  -74.9146
# 6         6          Sabang      ID  2021-12-05 22:50:41   5.8933   95.3214
# 12       12       Hithadhoo      MV  2021-12-05 22:53:11  -0.6000   73.0833
# 16       16           Ambon      ID  2021-12-05 22:53:12  -3.6954  128.1814
# 20       20      Butaritari      KI  2021-12-05 22:51:44   3.0707  172.7902
# 25       25       Kavaratti      IN  2021-12-05 22:53:14  10.5669   72.6420
# 27       27           Alofi      NU  2021-12-05 22:53:14 -19.0595 -169.9187
# 29       29        Takoradi      GH  2021-12-05 22:53:15   4.8845   -1.7554
# 69       69           Vaini      TO  2021-12-05 22:54:25 -21.2000 -175.2000
# 70       70  Cabo San Lucas      MX  2021-12-05 22:53:23  22.8909 -109.9124
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 1      84.15        76          43        8.43    scattered clouds
# 6      81.00        77          90       14.34     overcast clouds
# 12     81.27        78         100       12.30     overcast clouds
# 16     80.74        78          40       10.36    scattered clouds
# 20     80.82        83         100       11.97       moderate rain
# 25     80.69        72          60       12.48       broken clouds
# 27     80.49        78          71       19.57          light rain
# 29     80.56        84          48        8.72    scattered clouds
# 69     80.76        89          75       13.80       broken clouds
# 70     81.52        60         100        6.71     overcast clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 1 to 656
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              103 non-null    int64
#  1   City                 103 non-null    object
#  2   Country              103 non-null    object
#  3   Date                 103 non-null    object
#  4   Lat                  103 non-null    float64
#  5   Lng                  103 non-null    float64
#  6   Max Temp             103 non-null    float64
#  7   Humidity             103 non-null    int64
#  8   Cloudiness           103 non-null    int64
#  9   Wind Speed           103 non-null    float64
#  10  Current Description  103 non-null    object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 9.7+ KB

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.copy()
clean_df.dropna(how='any', inplace=True)
clean_df
# Out:
#      City_ID        City Country                 Date      Lat       Lng  \
# 1          1     Calamar      CO  2021-12-05 22:53:07  10.2511  -74.9146
# 6          6      Sabang      ID  2021-12-05 22:50:41   5.8933   95.3214
# 12        12   Hithadhoo      MV  2021-12-05 22:53:11  -0.6000   73.0833
# 16        16       Ambon      ID  2021-12-05 22:53:12  -3.6954  128.1814
# 20        20  Butaritari      KI  2021-12-05 22:51:44   3.0707  172.7902
# ..       ...         ...     ...                  ...      ...       ...
# 634      634   Manokwari      ID  2021-12-05 23:09:12  -0.8667  134.0833
# 640      640     Leticia      CO  2021-12-05 23:09:13  -4.2153  -69.9406
# 641      641     Waounde      SN  2021-12-05 23:09:13  15.2637  -12.8682
# 654      654    Waingapu      ID  2021-12-05 23:10:18  -9.6567  120.2641
# 656      656        Axim      GH  2021-12-05 23:07:04   4.8699   -2.2405
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 1       84.15        76          43        8.43    scattered clouds
# 6       81.00        77          90       14.34     overcast clouds
# 12      81.27        78         100       12.30     overcast clouds
# 16      80.74        78          40       10.36    scattered clouds
# 20      80.82        83         100       11.97       moderate rain
# ..        ...       ...         ...         ...                 ...
# 634     81.57        76          97        3.87     overcast clouds
# 640     78.85        94          75        3.44       broken clouds
# 641     80.92        13          99       10.40     overcast clouds
# 654     79.75        81         100        3.04          light rain
# 656     80.37        83          42        8.57    scattered clouds
#
# [103 rows x 11 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 1          Calamar      CO     84.15    scattered clouds  10.2511  -74.9146
# 6           Sabang      ID     81.00     overcast clouds   5.8933   95.3214
# 12       Hithadhoo      MV     81.27     overcast clouds  -0.6000   73.0833
# 16           Ambon      ID     80.74    scattered clouds  -3.6954  128.1814
# 20      Butaritari      KI     80.82       moderate rain   3.0707  172.7902
# 25       Kavaratti      IN     80.69       broken clouds  10.5669   72.6420
# 27           Alofi      NU     80.49          light rain -19.0595 -169.9187
# 29        Takoradi      GH     80.56    scattered clouds   4.8845   -1.7554
# 69           Vaini      TO     80.76       broken clouds -21.2000 -175.2000
# 70  Cabo San Lucas      MX     81.52     overcast clouds  22.8909 -109.9124
#
#    Hotel Name
# 1
# 6
# 12
# 16
# 20
# 25
# 27
# 29
# 69
# 70

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    # Grab the first hotel from the results and store the name.
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna(how='any')
clean_hotel_df
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 1       Calamar      CO     84.15    scattered clouds  10.2511  -74.9146
# 6        Sabang      ID     81.00     overcast clouds   5.8933   95.3214
# 12    Hithadhoo      MV     81.27     overcast clouds  -0.6000   73.0833
# 16        Ambon      ID     80.74    scattered clouds  -3.6954  128.1814
# 20   Butaritari      KI     80.82       moderate rain   3.0707  172.7902
# ..          ...     ...       ...                 ...      ...       ...
# 634   Manokwari      ID     81.57     overcast clouds  -0.8667  134.0833
# 640     Leticia      CO     78.85       broken clouds  -4.2153  -69.9406
# 641     Waounde      SN     80.92     overcast clouds  15.2637  -12.8682
# 654    Waingapu      ID     79.75          light rain  -9.6567  120.2641
# 656        Axim      GH     80.37    scattered clouds   4.8699   -2.2405
#
#                                             Hotel Name
# 1                                      Hostal Katyalex
# 6                                          Hotel Citra
# 12                                   Scoop Guest House
# 16                                Swiss-Belhotel Ambon
# 20                                  Isles Sunset Lodge
# ..                                                 ...
# 634                           Swiss Belhotel Manokwari
# 640  Hotel Amazon Bed and Breakfast / Hotel Amazon B&B
# 641
# 654                                 Pondok Wisata Elim
# 656                          Axim Beach Resort And Spa
#
# [103 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "./Weather_Database/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
hotel_info
# Out:
# ['\n<dl>\n<dt>City</dt><dd>Calamar</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>84.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sabang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ambon</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>80.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Weather Description</dt><dd>moderate rain</dd>\n<dt>Max Temp</dt><dd>80.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>80.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Takoradi</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cabo San Lucas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>moderate rain</dd>\n<dt>Max Temp</dt><dd>82.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Namatanai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Santa Maria</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>81.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Vila Velha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>78.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>84.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>San Policarpo</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>81.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>heavy intensity rain</dd>\n<dt>Max Temp</dt><dd>79.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ixtapa</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Santa Fe</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>80.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Suba</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Gold Coast</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Labuhan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Port Blair</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sorong</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>78.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cotonou</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>84.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Iguatemi</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Puerto Escondido</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>83.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bangkalan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Merauke</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Weather Description</dt><dd>moderate rain</dd>\n<dt>Max Temp</dt><dd>82.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bowen</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>84.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Lazaro Cardenas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>82.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>81.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>81.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sola</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mahibadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>82.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Hobyo</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Santiago Del Estero</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>82.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Xai-Xai</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Pemangkat</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>81.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Coahuayana</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Gamba</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>78.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ugoofaaru</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>81.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Port Lavaca</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ankazoabo</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kulhudhuffushi</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>81.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Beira</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>78.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kerema</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>81.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Daru</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Thinadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kaeo</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>78.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Male</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>81.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Paciran</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tulum</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bani</dd>\n<dt>Country</dt><dd>DO</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tual</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>82.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Saint-Louis</dd>\n<dt>Country</dt><dd>SN</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Lakatoro</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>83.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Grand Gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>78.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kribi</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Rivadavia</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>80.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bakel</dd>\n<dt>Country</dt><dd>SN</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mazatlan</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Gibara</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Isla Vista</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>83.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Quatre Cocos</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>78.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Acapulco</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>84.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Samarai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Pailitas</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Reconquista</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>82.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kuah</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mitsamiouli</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>80.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>80.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Katherine</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Pico Rivera</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>haze</dd>\n<dt>Max Temp</dt><dd>79.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Vanimo</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>84.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ternate</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Touros</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>81.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ende</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Marabba</dd>\n<dt>Country</dt><dd>SD</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>79.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mount Isa</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>San Patricio</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Paracuru</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>83.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cantaura</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Koumac</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>83.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kupang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>81.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>San Luis Rio Colorado</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>82.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>80.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Fuerte Olimpo</dd>\n<dt>Country</dt><dd>PY</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tevaitoa</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>81.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Manokwari</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Leticia</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Waounde</dd>\n<dt>Country</dt><dd>SN</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Waingapu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>79.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Axim</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>80.37 °F</dd>\n</dl>\n']

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure(center=(30.0,  31.0), zoom_level=1.5)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
